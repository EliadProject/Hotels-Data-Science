# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
df = pd.read_csv("hotels_data.csv")

from datetime import datetime
from dateutil.parser import parse

def get_datetime(date_str):
    return datetime.strptime(date_str, '%m/%d/%Y %H:%M')

df["DayDiff"] = DataFrame([get_datetime(val) for val in df["Checkin Date"]]) - DataFrame([get_datetime(val) for val in df["Snapshot Date"]])
df["WeekDay"] = DataFrame([get_datetime(val).weekday() for val in df["Checkin Date"]])
df["DiscountDiff"] = df["Original Price"] - df["Discount Price"]
df["DiscountPerc"] = (df["DiscountDiff"]/df["Original Price"]) * 100

# %% [markdown]
# ## Top 150 common hotels

# %%
df["Hotel_Count"] = df.groupby('Hotel Name')['Hotel Name'].transform('count')
df=df.sort_values(by=['Hotel_Count'],ascending=False)
df.head()
# Out:
#         Snapshot ID    Snapshot Date     Checkin Date  Days  Original Price  \
# 31635           213    9/7/2015 0:00   9/16/2015 0:00     5            1221
# 156866          554  12/15/2015 0:00  12/16/2015 0:00     5            1385
# 47452             3   7/18/2015 0:00   8/17/2015 0:00     5            1177
# 47453             3   7/18/2015 0:00   8/18/2015 0:00     5            1194
# 47454             3   7/18/2015 0:00   8/18/2015 0:00     5            1194
#
#         Discount Price  Discount Code  Available Rooms  \
# 31635             1009              2               -1
# 156866             925              1                4
# 47452             1052              4               -1
# 47453              861              2               -1
# 47454              944              3               -1
#
#                                            Hotel Name  Hotel Stars DayDiff  \
# 31635   Newark Liberty International Airport Marriott            4  9 days
# 156866  Newark Liberty International Airport Marriott            4  1 days
# 47452   Newark Liberty International Airport Marriott            4 30 days
# 47453   Newark Liberty International Airport Marriott            4 31 days
# 47454   Newark Liberty International Airport Marriott            4 31 days
#
#         WeekDay  DiscountDiff  DiscountPerc  Hotel_Count
# 31635         2           212     17.362817         5346
# 156866        2           460     33.212996         5346
# 47452         0           125     10.620221         5346
# 47453         1           333     27.889447         5346
# 47454         1           250     20.938023         5346

# %%
DataFrame.duplicated(subset=df, keep='False')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-5ac702326e82> in <module>()
# ----> 1 DataFrame.duplicated(this,subset=df, keep='False')
#
# NameError: name 'this' is not defined

# %% [markdown]
# ## Top 40 checkins contain most lists
