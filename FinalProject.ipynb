# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %% [markdown]
# # Part 1

# %%
df = pd.read_csv("hotels_data.csv")
df.head()
# Out:
#    Snapshot ID   Snapshot Date    Checkin Date  Days  Original Price  \
# 0            1  7/17/2015 0:00  8/12/2015 0:00     5            1178
# 1            1  7/17/2015 0:00  8/19/2015 0:00     5            1113
# 2            1  7/17/2015 0:00  8/13/2015 0:00     5            4370
# 3            1  7/17/2015 0:00  7/26/2015 0:00     5            1739
# 4            1  7/17/2015 0:00  8/12/2015 0:00     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars
# 0  Best Western Plus Seaport Inn Downtown            3
# 1  Best Western Plus Seaport Inn Downtown            3
# 2                  The Peninsula New York            5
# 3            Eventi Hotel a Kimpton Hotel            4
# 4            Eventi Hotel a Kimpton Hotel            4

# %%
# 1.a
from datetime import datetime
from dateutil.parser import parse

def get_datetime(date_str):
    return datetime.strptime(date_str, '%m/%d/%Y %H:%M')

df["DayDiff"] = DataFrame([get_datetime(val) for val in df["Checkin Date"]]) - DataFrame([get_datetime(val) for val in df["Snapshot Date"]])
df.head()
# Out:
#    Snapshot ID   Snapshot Date    Checkin Date  Days  Original Price  \
# 0            1  7/17/2015 0:00  8/12/2015 0:00     5            1178
# 1            1  7/17/2015 0:00  8/19/2015 0:00     5            1113
# 2            1  7/17/2015 0:00  8/13/2015 0:00     5            4370
# 3            1  7/17/2015 0:00  7/26/2015 0:00     5            1739
# 4            1  7/17/2015 0:00  8/12/2015 0:00     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars DayDiff
# 0  Best Western Plus Seaport Inn Downtown            3 26 days
# 1  Best Western Plus Seaport Inn Downtown            3 33 days
# 2                  The Peninsula New York            5 27 days
# 3            Eventi Hotel a Kimpton Hotel            4  9 days
# 4            Eventi Hotel a Kimpton Hotel            4 26 days

# %%
#1.b

df["WeekDay"] = DataFrame([get_datetime(val).weekday() for val in df["Checkin Date"]])
df.head()
# Out:
#    Snapshot ID   Snapshot Date    Checkin Date  Days  Original Price  \
# 0            1  7/17/2015 0:00  8/12/2015 0:00     5            1178
# 1            1  7/17/2015 0:00  8/19/2015 0:00     5            1113
# 2            1  7/17/2015 0:00  8/13/2015 0:00     5            4370
# 3            1  7/17/2015 0:00  7/26/2015 0:00     5            1739
# 4            1  7/17/2015 0:00  8/12/2015 0:00     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars DayDiff  WeekDay
# 0  Best Western Plus Seaport Inn Downtown            3 26 days        2
# 1  Best Western Plus Seaport Inn Downtown            3 33 days        2
# 2                  The Peninsula New York            5 27 days        3
# 3            Eventi Hotel a Kimpton Hotel            4  9 days        6
# 4            Eventi Hotel a Kimpton Hotel            4 26 days        2

# %%
#1.c

df["DiscountDiff"] = df["Original Price"] - df["Discount Price"]
df.head()
# Out:
#    Snapshot ID   Snapshot Date    Checkin Date  Days  Original Price  \
# 0            1  7/17/2015 0:00  8/12/2015 0:00     5            1178
# 1            1  7/17/2015 0:00  8/19/2015 0:00     5            1113
# 2            1  7/17/2015 0:00  8/13/2015 0:00     5            4370
# 3            1  7/17/2015 0:00  7/26/2015 0:00     5            1739
# 4            1  7/17/2015 0:00  8/12/2015 0:00     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars DayDiff  WeekDay  \
# 0  Best Western Plus Seaport Inn Downtown            3 26 days        2
# 1  Best Western Plus Seaport Inn Downtown            3 33 days        2
# 2                  The Peninsula New York            5 27 days        3
# 3            Eventi Hotel a Kimpton Hotel            4  9 days        6
# 4            Eventi Hotel a Kimpton Hotel            4 26 days        2
#
#    DiscountDiff
# 0           138
# 1           131
# 2           130
# 3            72
# 4            67

# %%
#1.d

df["DiscountPerc"] = (df["DiscountDiff"]/df["Original Price"]) * 100
df.head()
# Out:
#    Snapshot ID   Snapshot Date    Checkin Date  Days  Original Price  \
# 0            1  7/17/2015 0:00  8/12/2015 0:00     5            1178
# 1            1  7/17/2015 0:00  8/19/2015 0:00     5            1113
# 2            1  7/17/2015 0:00  8/13/2015 0:00     5            4370
# 3            1  7/17/2015 0:00  7/26/2015 0:00     5            1739
# 4            1  7/17/2015 0:00  8/12/2015 0:00     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars DayDiff  WeekDay  \
# 0  Best Western Plus Seaport Inn Downtown            3 26 days        2
# 1  Best Western Plus Seaport Inn Downtown            3 33 days        2
# 2                  The Peninsula New York            5 27 days        3
# 3            Eventi Hotel a Kimpton Hotel            4  9 days        6
# 4            Eventi Hotel a Kimpton Hotel            4 26 days        2
#
#    DiscountDiff  DiscountPerc
# 0           138     11.714771
# 1           131     11.769991
# 2           130      2.974828
# 3            72      4.140311
# 4            67      3.852789

# %%
#Save df to csv
df.to_csv("Hotels_data_Changed.csv")

# %% [markdown]
# # Part 2

# %%
# 2.a

# dropping passed columns 
filtered_df = df.filter(["Hotel Name","DayDiff", "Checkin Date", "Snapshot Date", "WeekDay", "DiscountDiff", "Discount Code"], axis=1)
filtered_df.head()
#filtered_df.to_csv("Hotels_data_for_best_discount_code.csv")
# Out:
#                                Hotel Name DayDiff    Checkin Date  \
# 0  Best Western Plus Seaport Inn Downtown 26 days  8/12/2015 0:00
# 1  Best Western Plus Seaport Inn Downtown 33 days  8/19/2015 0:00
# 2                  The Peninsula New York 27 days  8/13/2015 0:00
# 3            Eventi Hotel a Kimpton Hotel  9 days  7/26/2015 0:00
# 4            Eventi Hotel a Kimpton Hotel 26 days  8/12/2015 0:00
#
#     Snapshot Date  WeekDay  DiscountDiff  Discount Code
# 0  7/17/2015 0:00        2           138              1
# 1  7/17/2015 0:00        2           131              1
# 2  7/17/2015 0:00        3           130              1
# 3  7/17/2015 0:00        6            72              1
# 4  7/17/2015 0:00        2            67              1

# %%
filtered_df["MaxDis"] = filtered_df.groupby(["Hotel Name","DayDiff", "Checkin Date", "Snapshot Date", "WeekDay"])["DiscountDiff"].transform('max')
#filtered_df.sort_values(by=["Hotel Name","DayDiff", "Checkin Date", "Snapshot Date", "WeekDay"],ascending=False).reset_index()

grouped_df = filtered_df[filtered_df["DiscountDiff"]==filtered_df["MaxDis"]].drop_duplicates(["Hotel Name","DayDiff", "Checkin Date", "Snapshot Date", "WeekDay"])
grouped_df.drop(labels=["MaxDis","DiscountDiff"], axis=1,inplace=True)
grouped_df.head()
grouped_df.to_csv("Hotels_data_for_best_discount_code_grouped.csv")
# Debug stuff for find the correct data 
#grouped_df.loc[(for_learn_df["Hotel Name"] == "1 Hotel Central Park") & (for_learn_df["DayDiff"] == "3 days") & (for_learn_df["Checkin Date"] == "11/14/2015 0:00") ]

# %%
# 2.b
pred_df = grouped_df.copy()
pred_df.head()
# Out:
#                                Hotel Name DayDiff    Checkin Date  \
# 0  Best Western Plus Seaport Inn Downtown 26 days  8/12/2015 0:00
# 1  Best Western Plus Seaport Inn Downtown 33 days  8/19/2015 0:00
# 3            Eventi Hotel a Kimpton Hotel  9 days  7/26/2015 0:00
# 5                    Grand Hyatt New York 21 days   8/7/2015 0:00
# 6                    Grand Hyatt New York 23 days   8/9/2015 0:00
#
#     Snapshot Date  WeekDay  Discount Code
# 0  7/17/2015 0:00        2              1
# 1  7/17/2015 0:00        2              1
# 3  7/17/2015 0:00        6              1
# 5  7/17/2015 0:00        4              1
# 6  7/17/2015 0:00        6              1

# %%
from sklearn.preprocessing import LabelEncoder

#we found that there is a problem of imbalnce classes so, we decided to take only part of data of each class , in the same size
#in that aprouch we make a sugnificent improvement from 33% accuracy in navie base to 38%.
ShouldShowClassBalancing=False;

Class1=""
if ShouldShowClassBalancing:
    Class4=pred_df[pred_df['Discount Code']==4].head(10000)
    Class3=pred_df[pred_df['Discount Code']==3].head(10000)
    Class2=pred_df[pred_df['Discount Code']==2].head(10000)
    Class1=pred_df[pred_df['Discount Code']==1].head(10000)
    Class1=Class1.append(Class2)
    Class1=Class1.append(Class3)
    Class1=Class1.append(Class4)
else:
    Class1=pred_df.copy();



pred_df=Class1.copy()

pred_categorized_df=Class1.copy()

le=LabelEncoder()

# pre process - convert columns to categorial numebr instead of strings so fit will work.
pred_categorized_df["CheckinDate"]=le.fit_transform(pred_categorized_df["Checkin Date"])
pred_categorized_df["HotelName"]=le.fit_transform(pred_categorized_df["Hotel Name"])
pred_categorized_df["SnapshotDate"]=le.fit_transform(pred_categorized_df["Snapshot Date"])
pred_categorized_df["DayDiff"] = [t.days for t in pred_categorized_df["DayDiff"]] # convert timedelta to days

#print(pred_categorized_df[pred_categorized_df["Discount Code"]==1])
#print(pred_categorized_df[pred_categorized_df["Discount Code"]==2])
#print(pred_categorized_df[pred_categorized_df["Discount Code"]==3])
#print(pred_categorized_df[pred_categorized_df["Discount Code"]==4])

# remove target column "Discount Code" from data frame used for learning.
pred_categorized_df.drop(labels=["Discount Code","Checkin Date","Snapshot Date","Hotel Name"],axis=1, inplace=True)

# %% [markdown]
# # Normal distribution check

# %%
pred_categorized_df.describe()
#we see here that mean is approxmetly the same as median (50%) so its probably distributes as noraml distribution
# Out:
#              DayDiff        WeekDay    CheckinDate      HotelName  \
# count  107299.000000  107299.000000  107299.000000  107299.000000
# mean       17.328400       2.937828     102.829290     284.663492
# std        10.031845       1.869531      56.145063     149.065930
# min         1.000000       0.000000       0.000000       0.000000
# 25%         9.000000       1.000000      55.000000     174.000000
# 50%        17.000000       3.000000      91.000000     273.000000
# 75%        26.000000       4.000000     157.000000     397.000000
# max        34.000000       6.000000     201.000000     553.000000
#
#         SnapshotDate
# count  107299.000000
# mean       72.247244
# std        44.205223
# min         0.000000
# 25%        32.000000
# 50%        70.000000
# 75%       111.000000
# max       150.000000

# %% [markdown]
# # Naive Bayes - All train All test

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
#print(pred_categorized_df.head(5))
#print(len(pred_categorized_df))
y_pred = gnb.fit(pred_categorized_df, pred_df['Discount Code']).predict(pred_categorized_df)

#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(pred_df['Discount Code'], y_pred))
# Out:
# Accuracy: 0.33955582065070505

# %% [markdown]
# # Cross Validation

# %%
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(pred_categorized_df, pred_df['Discount Code'], test_size=0.3,random_state=0) # 70% training and 30% test

X_train, X_test, y_train, y_test
# Out:
# C:\Users\roei\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# (        DayDiff  WeekDay  CheckinDate  HotelName  SnapshotDate
#  184387       23        5          197         13            97
#  30154        15        6          184        192           146
#  85231        34        5           67        194             3
#  44209         4        5          182        530           130
#  184596       27        0          149        321            84
#  122575        7        6          135        299            82
#  116864        9        2           64        529            42
#  40444        33        4           38        141           128
#  102253        2        5           47        314            15
#  171603       34        5           23        170            75
#  111652       19        1           70        544            22
#  135865       23        2          122        191            38
#  149221       31        1          113        463            49
#  131775        8        3           72        326            34
#  95406         4        3           45         16            10
#  143356        1        0           77        244            45
#  46069         9        4          189        203           131
#  127999       10        2           71        334            56
#  44479         7        1          166        191            91
#  137481       28        1           98        526            39
#  18755        21        3          180        199           112
#  94920        12        3           52        189             9
#  141355       34        3          108         25            43
#  86086        15        1           50        374             4
#  184163        5        1          150        341            97
#  19104         8        4          196        154           112
#  129778       13        0           77        163            33
#  58048        27        5           39        192           136
#  147695        6        3          114        163            48
#  57824        33        4           46        485           136
#  ...         ...      ...          ...        ...           ...
#  14573         8        4          140        285            86
#  65310        34        5           55        544           142
#  122608        1        4          169        428           120
#  117532       26        6           83        113            51
#  67208         5        0           57        112           144
#  11917        10        2          183        292           108
#  182874       16        4          161        408            96
#  162064       17        0           25        370            66
#  143305       29        0          105        171            45
#  177194        5        3          145        169           122
#  156077        8        1          106        529            62
#  34012        18        2          144        272            88
#  56423        16        0           57        413           134
#  30982        31        2           59        196           147
#  139382       34        2          107        172            41
#  91343        32        1           70        192             8
#  68359        14        3           37        290             1
#  84470        20        5           55         31             3
#  140707       11        1           92        199            43
#  139838        9        5           82        544            41
#  95594         5        4           46        363            10
#  150024       16        1           98        199            50
#  72669        32        2           86        472            23
#  170593       24        1           10        285            74
#  167417        7        2          115        197            71
#  37792        10        2          167        190            89
#  79906         1        3           60        180            29
#  73726        20        5           47         73            26
#  75690        32        4           88        141            27
#  118544       13        0           69        544            51
#
#  [75109 rows x 5 columns],
#          DayDiff  WeekDay  CheckinDate  HotelName  SnapshotDate
#  181809       24        4          196         47            95
#  133546       28        5           95        434            36
#  91504        11        1           50        506             8
#  94952        13        4           54         17             9
#  34285        18        2          144        171            88
#  278          24        0          142        341            80
#  141730       33        3          108        154            44
#  107017       13        6           90        189            19
#  46272        26        0           34        538           131
#  173715       15        2            4        529            77
#  45492        17        4          146        191            91
#  184270       11        0          157        334            97
#  69520        13        2           36        192             1
#  132524       18        0           85        112            35
#  82595        21        4           54        301            31
#  139681        7        3           80        444            41
#  28299        11        1          166        223            87
#  45809        20        1           58        528           131
#  145652       19        5           95        398            46
#  156385       28        0            2        304            62
#  97470         4        4           46         25            11
#  121843       17        2          167        200            82
#  166877        6        1          113        321            71
#  117468       26        6           83        224            51
#  128893       29        1          121        290            57
#  67743        22        3           45        273           144
#  55198        22        2          159        492           118
#  66190        29        2           51        528           143
#  52268        10        3          145        526           115
#  103082       16        6           90        224            16
#  ...         ...      ...          ...        ...           ...
#  52241         2        2          167        114           115
#  22283        31        2          195        525           116
#  154359       19        3          116        544            60
#  115469       31        2          103        538            32
#  65126        25        3           45        529           142
#  65583        24        2           44        191           142
#  182577       18        6          164        301            96
#  104240       17        1           63         98            17
#  24564        28        0          192        434           117
#  2948         24        3          173        434           101
#  38152        33        2           36        171           126
#  153151       17        0          112        174            59
#  90620        12        1           50        373             7
#  130928       14        2           79        374            34
#  38833        11        1          186        370           126
#  162616        7        5          110        334            67
#  5689         16        3          194        110           102
#  145337        4        4           81        178            46
#  29384         2        6          198        292           145
#  56336         7        1          143        349           118
#  180096       12        5          155        186            94
#  117413       15        2           71        398            51
#  8560          9        6          164        196           106
#  150871       29        0          112         16            50
#  114543        9        0           91        299            25
#  24491         2        2          183        174           117
#  162077       13        3          116        374            66
#  68351         8        4           61        506             1
#  88988         4        6           40         31             6
#  153661        2        0           97         21            60
#
#  [32190 rows x 5 columns],
#  184387    3
#  30154     3
#  85231     3
#  44209     4
#  184596    1
#  122575    2
#  116864    3
#  40444     2
#  102253    3
#  171603    3
#  111652    3
#  135865    1
#  149221    3
#  131775    3
#  95406     1
#  143356    2
#  46069     2
#  127999    4
#  44479     1
#  137481    2
#  18755     3
#  94920     3
#  141355    3
#  86086     2
#  184163    3
#  19104     4
#  129778    2
#  58048     2
#  147695    3
#  57824     2
#           ..
#  14573     1
#  65310     2
#  122608    1
#  117532    1
#  67208     1
#  11917     4
#  182874    2
#  162064    3
#  143305    2
#  177194    2
#  156077    2
#  34012     3
#  56423     1
#  30982     3
#  139382    1
#  91343     1
#  68359     1
#  84470     1
#  140707    2
#  139838    2
#  95594     1
#  150024    2
#  72669     3
#  170593    3
#  167417    3
#  37792     4
#  79906     4
#  73726     2
#  75690     2
#  118544    3
#  Name: Discount Code, Length: 75109, dtype: int64,
#  181809    2
#  133546    2
#  91504     2
#  94952     3
#  34285     4
#  278       2
#  141730    1
#  107017    2
#  46272     3
#  173715    4
#  45492     4
#  184270    3
#  69520     4
#  132524    2
#  82595     3
#  139681    2
#  28299     4
#  45809     2
#  145652    4
#  156385    3
#  97470     2
#  121843    2
#  166877    1
#  117468    1
#  128893    3
#  67743     2
#  55198     1
#  66190     2
#  52268     2
#  103082    2
#           ..
#  52241     2
#  22283     2
#  154359    3
#  115469    3
#  65126     2
#  65583     3
#  182577    1
#  104240    2
#  24564     3
#  2948      3
#  38152     2
#  153151    3
#  90620     3
#  130928    1
#  38833     4
#  162616    1
#  5689      4
#  145337    3
#  29384     4
#  56336     4
#  180096    1
#  117413    1
#  8560      2
#  150871    4
#  114543    4
#  24491     2
#  162077    3
#  68351     1
#  88988     2
#  153661    1
#  Name: Discount Code, Length: 32190, dtype: int64)

# %% [markdown]
# # Naive Bayes - 0.3/0.7

# %%
#Import Gaussian Naive Bayes model
from sklearn.naive_bayes import GaussianNB

#Create a Gaussian Classifier
gnb = GaussianNB()

#Train the model using the training sets
gnb.fit(X_train, y_train)

#Predict the response for test dataset
y_pred2 = gnb.predict(X_test)
y_pred2

#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred2))
# Out:
# Accuracy: 0.33749611680646163

# %% [markdown]
# # metrics for fp,tp and etc

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
cm = confusion_matrix(y_test, y_pred2)

plt.figure()
plot_confusion_matrix(cm, classes=pred_df["Discount Code"].unique(),
                      title='Confusion matrix, without normalization')
# Out:
# Confusion matrix, without normalization
# [[1575 5402 1455    0]
#  [1338 6281 2646    0]
#  [ 597 4842 3008    0]
#  [ 415 3343 1288    0]]

# %%
# cm.sum(axis=0) return array of size 4(=classes num), which every item is sum of predictions for class

FP = cm.sum(axis=0) - np.diag(cm)  # foreach class: sum prediction - TP
FN = cm.sum(axis=1) - np.diag(cm)  # foreach class: sum actuals - TP
TP = np.diag(cm)
TN = cm.sum() - (FP + FN + TP)

FP = FP.astype(float)
FN = FN.astype(float)
TP = TP.astype(float)
TN = TN.astype(float)


def printRates(array, stat):
    print("%s for classes:" %stat)
    for i in range(len(array)):
        print("\tclass %d = %f" %(i+1, array[i]))
    print("")
    
printRates(FP, "FP")
printRates(FN, "FN")
printRates(TP, "TP")
printRates(TN, "TN")

# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
printRates(TPR, "TPR")

# Specificity or true negative rate
TNR = TN/(TN+FP) 
printRates(TNR, "TNR")

# Precision or positive predictive value
PPV = TP/(TP+FP)
printRates(PPV, "PPV")

# Negative predictive value
NPV = TN/(TN+FN)
printRates(NPV, "NPV")

# Fall out or false positive rate
FPR = FP/(FP+TN)
printRates(FPR, "FPR")

# False negative rate
FNR = FN/(TP+FN)
printRates(FNR, "FNR")

# False discovery rate
FDR = FP/(TP+FP)
printRates(FDR, "FDR")

# Overall accuracy
ACC = (TP+TN)/(TP+FP+FN+TN)
printRates(ACC, "ACC")
# Out:
# FP for classes:
# 	class 1 = 2350.000000
# 	class 2 = 13587.000000
# 	class 3 = 5389.000000
# 	class 4 = 0.000000
#
# FN for classes:
# 	class 1 = 6857.000000
# 	class 2 = 3984.000000
# 	class 3 = 5439.000000
# 	class 4 = 5046.000000
#
# TP for classes:
# 	class 1 = 1575.000000
# 	class 2 = 6281.000000
# 	class 3 = 3008.000000
# 	class 4 = 0.000000
#
# TN for classes:
# 	class 1 = 21408.000000
# 	class 2 = 8338.000000
# 	class 3 = 18354.000000
# 	class 4 = 27144.000000
#
# TPR for classes:
# 	class 1 = 0.186788
# 	class 2 = 0.611885
# 	class 3 = 0.356103
# 	class 4 = 0.000000
#
# TNR for classes:
# 	class 1 = 0.901086
# 	class 2 = 0.380296
# 	class 3 = 0.773028
# 	class 4 = 1.000000
#
# PPV for classes:
# 	class 1 = 0.401274
# 	class 2 = 0.316137
# 	class 3 = 0.358223
# 	class 4 = nan
#
# NPV for classes:
# 	class 1 = 0.757403
# 	class 2 = 0.676676
# 	class 3 = 0.771403
# 	class 4 = 0.843243
#
# FPR for classes:
# 	class 1 = 0.098914
# 	class 2 = 0.619704
# 	class 3 = 0.226972
# 	class 4 = 0.000000
#
# FNR for classes:
# 	class 1 = 0.813212
# 	class 2 = 0.388115
# 	class 3 = 0.643897
# 	class 4 = 1.000000
#
# FDR for classes:
# 	class 1 = 0.598726
# 	class 2 = 0.683863
# 	class 3 = 0.641777
# 	class 4 = nan
#
# ACC for classes:
# 	class 1 = 0.713979
# 	class 2 = 0.454147
# 	class 3 = 0.663622
# 	class 4 = 0.843243
# C:\Users\roei\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\roei\Anaconda3\lib\site-packages\ipykernel_launcher.py:50: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# # Decision tree - cross validation

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier(criterion ="entropy")#,max_depth=3)

#Train the model using the training sets
clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred3 = clf.predict(X_test)
y_pred3

#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred3))

y_pred3
# Out:
# Accuracy: 0.7709537123330227
# array([3, 2, 2, ..., 1, 1, 1], dtype=int64)

# %%
#Draw the Tree in order to get the most effective featrue by IG  
import graphviz 
import matplotlib.image as mpimg
PrintTree=False
if PrintTree:
    dot_data = tree.export_graphviz(clf, out_file=None, feature_names=pred_categorized_df.columns.values,filled=True, rounded=True,special_characters=True)  
    graph = graphviz.Source(dot_data) 
    graph.render("Hotel Data Science")
    graph

# %%
cm = confusion_matrix(y_test, y_pred3)

plt.figure()
plot_confusion_matrix(cm, classes=pred_df["Discount Code"].unique(),
                      title='Confusion matrix, without normalization')
# Out:
# Confusion matrix, without normalization
# [[6460 1003  589  380]
#  [ 901 8016  937  411]
#  [ 550  874 6545  478]
#  [ 372  395  483 3796]]

# %% [markdown]
# # FP , TP and etc...

# %%
cm.sum(axis=0),np.diag(cm) ,cm.sum()
# Out:
# (array([ 8283, 10288,  8554,  5065], dtype=int64),
#  array([6460, 8016, 6545, 3796], dtype=int64),
#  32190)

# %%
# cm.sum(axis=0) return array of size 4(=classes num), which every item is sum of predictions for class

FP = cm.sum(axis=0) - np.diag(cm)  # foreach class: sum prediction - TP
FN = cm.sum(axis=1) - np.diag(cm)  # foreach class: sum actuals - TP
TP = np.diag(cm)
TN = cm.sum() - (FP + FN + TP)

FP = FP.astype(float)
FN = FN.astype(float)
TP = TP.astype(float)
TN = TN.astype(float)


def printRates(array, stat):
    print("%s for classes:" %stat)
    for i in range(len(array)):
        print("\tclass %d = %f" %(i+1, array[i]))
    print("")
    
printRates(FP, "FP")
printRates(FN, "FN")
printRates(TP, "TP")
printRates(TN, "TN")

# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
printRates(TPR, "TPR")

# Specificity or true negative rate
TNR = TN/(TN+FP) 
printRates(TNR, "TNR")

# Precision or positive predictive value
PPV = TP/(TP+FP)
printRates(PPV, "PPV")

# Negative predictive value
NPV = TN/(TN+FN)
printRates(NPV, "NPV")

# Fall out or false positive rate
FPR = FP/(FP+TN)
printRates(FPR, "FPR")

# False negative rate
FNR = FN/(TP+FN)
printRates(FNR, "FNR")

# False discovery rate
FDR = FP/(TP+FP)
printRates(FDR, "FDR")

# Overall accuracy
ACC = (TP+TN)/(TP+FP+FN+TN)
printRates(ACC, "ACC")
# Out:
# FP for classes:
# 	class 1 = 1823.000000
# 	class 2 = 2272.000000
# 	class 3 = 2009.000000
# 	class 4 = 1269.000000
#
# FN for classes:
# 	class 1 = 1972.000000
# 	class 2 = 2249.000000
# 	class 3 = 1902.000000
# 	class 4 = 1250.000000
#
# TP for classes:
# 	class 1 = 6460.000000
# 	class 2 = 8016.000000
# 	class 3 = 6545.000000
# 	class 4 = 3796.000000
#
# TN for classes:
# 	class 1 = 21935.000000
# 	class 2 = 19653.000000
# 	class 3 = 21734.000000
# 	class 4 = 25875.000000
#
# TPR for classes:
# 	class 1 = 0.766129
# 	class 2 = 0.780906
# 	class 3 = 0.774831
# 	class 4 = 0.752279
#
# TNR for classes:
# 	class 1 = 0.923268
# 	class 2 = 0.896374
# 	class 3 = 0.915386
# 	class 4 = 0.953249
#
# PPV for classes:
# 	class 1 = 0.779911
# 	class 2 = 0.779160
# 	class 3 = 0.765139
# 	class 4 = 0.749457
#
# NPV for classes:
# 	class 1 = 0.917514
# 	class 2 = 0.897315
# 	class 3 = 0.919530
# 	class 4 = 0.953917
#
# FPR for classes:
# 	class 1 = 0.076732
# 	class 2 = 0.103626
# 	class 3 = 0.084614
# 	class 4 = 0.046751
#
# FNR for classes:
# 	class 1 = 0.233871
# 	class 2 = 0.219094
# 	class 3 = 0.225169
# 	class 4 = 0.247721
#
# FDR for classes:
# 	class 1 = 0.220089
# 	class 2 = 0.220840
# 	class 3 = 0.234861
# 	class 4 = 0.250543
#
# ACC for classes:
# 	class 1 = 0.882106
# 	class 2 = 0.859553
# 	class 3 = 0.878503
# 	class 4 = 0.921746

# %% [markdown]
# # ROC

# %%
#pd.get_dummies(y_pred3)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve,auc
from scipy import interp
# %matplotlib inline

def PlotRoc(classifier_type, pred,n_classes):
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    
    for i in range(n_classes):
        print(i)
        fpr[i], tpr[i], _ = roc_curve(np.array(pd.get_dummies(y_test))[:, i], np.array(pd.get_dummies(pred))[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])


    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    lw=2
    plt.figure(figsize=(8,5))
    plt.plot(fpr["macro"], tpr["macro"],
             label='macro-average ROC curve (area = {0:0.2f})'
                   ''.format(roc_auc["macro"]),
             color='green', linestyle=':', linewidth=4)

    colors = ['aqua', 'darkorange', 'cornflowerblue', 'yellow']
    for i, color in zip(range(n_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=lw,
                 label='ROC curve of class {0} (area = {1:0.2f})'
                 ''.format(i, roc_auc[i]))

    plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.annotate('Random Guess',(.5,.48),color='red')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC - '+classifier_type)
    plt.legend(loc="lower right")
    plt.show()
    
if ShouldShowClassBalancing:   
    PlotRoc("Naive Bayes", y_pred2,4)
else: 
    PlotRoc("Naive Bayes", y_pred2,3)
PlotRoc("Decision Tree", y_pred3,4)
# Out:
# 0
# 1
# 2
# 0
# 1
# 2
# 3

# %% [markdown]
# # Result Explanation:
# <div>1.we see that naive bayes accuracy result is 34% aproximettly</div>
#
# <div>2.we see that decision tree accuray result is 77% aproximettly</div>
#
# <div>we saw that even when we use all train data for train and predict the result of the naive bayes stay the same.</div>
#
# <div> also , we can conclude from the confusion matrix of the naive bayes that we have a problem of <h5>imbalanced classes (in our case class 4).</h5> </div>
#
# <div><h3>the explention for the big gap between the results of the naive bayes and decision tree might be :</h3></div>
# decission tree is an algorithem which calculate the best  Information gain and classifies first by that feature also if we dont limit the tree width the decitsion tree algorithem tends to be over-fitting,
# naive bayes is an alogirhtem which uses probabilites of features and is efected much more by frequent features. therefore when we have less data on a specific class the naive bayes not likley to predict him.
#
# <div><h5>in order to fix the problem we made several attempts include:</h5></div>
# <div> duplicate class 4 data and add to all other data which made no progress, and finally, take only some of data from each class (10000) and calculate the naive bayes according to that data-set</div>
# <div> using the secound approuch improved the accuracy result in 5% percent which reflected immediately in the roc graph and confusion matrix of the naive bayes.</div>
#
# <div><h3>The most efective features are:</h3></div>
# <div>Hotel Name and WeekDay</div>
# <div> when building the decision tree graph -we can see that the IG of those feautres are the best </div>

# %% [markdown]
# # Print Graph of each features to each feautre trying to find corelation bettwen them
# finding that there is some corleation bettwen Snapshot date to checking date, not a big improvement when dropping one of them

# %%
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

norma_train=X_train.copy()

norma_train["HotelName"]=pd.to_numeric(norma_train["HotelName"])
norma_train["CheckinDate"]=pd.to_numeric(norma_train["CheckinDate"])
norma_train["SnapshotDate"]=pd.to_numeric(norma_train["SnapshotDate"])

#pd.scatter_matrix(norma_train,alpha=0.1,figsize=(14,8),diagonal='kde')

sns.pairplot(norma_train.dropna())
print(norma_train.describe())
# Out:
#             DayDiff       WeekDay   CheckinDate     HotelName  SnapshotDate
# count  75109.000000  75109.000000  75109.000000  75109.000000  75109.000000
# mean      17.318218      2.932085    102.967634    283.885100     72.366161
# std       10.041761      1.871884     56.113401    149.115842     44.229856
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%        9.000000      1.000000     55.000000    174.000000     32.000000
# 50%       17.000000      3.000000     91.000000    273.000000     70.000000
# 75%       26.000000      4.000000    157.000000    397.000000    111.000000
# max       34.000000      6.000000    201.000000    553.000000    150.000000

# %%
pd.get_dummies(y_pred)
# Out:
#         1  2  3
# 0       0  0  1
# 1       0  0  1
# 2       1  0  0
# 3       0  1  0
# 4       1  0  0
# 5       0  1  0
# 6       0  1  0
# 7       0  1  0
# 8       1  0  0
# 9       1  0  0
# 10      0  1  0
# 11      0  0  1
# 12      1  0  0
# 13      0  1  0
# 14      0  0  1
# 15      0  1  0
# 16      0  1  0
# 17      0  1  0
# 18      0  1  0
# 19      0  1  0
# 20      0  1  0
# 21      0  1  0
# 22      1  0  0
# 23      1  0  0
# 24      1  0  0
# 25      1  0  0
# 26      1  0  0
# 27      0  1  0
# 28      0  1  0
# 29      0  1  0
# ...    .. .. ..
# 107269  0  0  1
# 107270  0  1  0
# 107271  1  0  0
# 107272  0  1  0
# 107273  0  0  1
# 107274  0  1  0
# 107275  0  1  0
# 107276  0  1  0
# 107277  0  1  0
# 107278  1  0  0
# 107279  0  1  0
# 107280  0  1  0
# 107281  0  1  0
# 107282  0  1  0
# 107283  0  1  0
# 107284  1  0  0
# 107285  0  1  0
# 107286  0  1  0
# 107287  0  1  0
# 107288  0  1  0
# 107289  0  0  1
# 107290  0  1  0
# 107291  0  1  0
# 107292  0  1  0
# 107293  0  1  0
# 107294  0  0  1
# 107295  0  1  0
# 107296  0  1  0
# 107297  0  1  0
# 107298  0  1  0
#
# [107299 rows x 3 columns]
